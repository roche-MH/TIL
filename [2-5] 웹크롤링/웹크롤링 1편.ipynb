# %%
import urllib.request
# URL과 저장 경로 지정하기
url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"
# 다운로드 
urllib.request.urlretrieve(url, savename)
print("저장되었습니다...!")

# urlopen()을 이용한 다운로드

mem = urllib.request.urlopen(url).read()



with open(savename, mode="wb") as f:  # wb가 아닌 w로 하면 다운은 되지만 파일을 열수가 없다.

    f.write(mem)

    print('저장되었습니다.')

savename
# Out:
# 저장되었습니다...!
# 저장되었습니다.
# 'test.png'

# %%
import urllib.request
import urllib.parse
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
values= {
    'stnld':'108' ## stnld는 기상 정보를 알고 싶은 지역
}
params = urllib.parse.urlencode(values)
#요청 전용 url 을 생성합니다.
url = API + "?" + params
#다운로드 합니다.
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2019년 12월 24일 (화)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2019년 12월 24일 (화)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>201912240600</tm>
# 		<wf><![CDATA[기압골의 영향으로 29~30일은 남부지방과 제주도에 비가 오겠습니다. 그 밖의 날은 고기압의 가장자리에 들어 가끔 구름이 많겠습니다.<br />기온은 평년(최저기온: -11~1℃, 최고기온: 1~9℃)보다 높겠습니다.<br />강수량은 평년(0~2mm)보다 많겠으나, 중부지방은 적겠습니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>-1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>-2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-11</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>강원도영서</province>
# 				<city>춘천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>강원도영서</province>
# 				<city>원주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>강원도영동</province>
# 				<city>강릉</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>3</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>3</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>대전</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>세종</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>홍성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>청주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>1</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>충주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>0</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>영동</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-10</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>5</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>5</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>목포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>4</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>여수</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>6</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>8</tmx>
# ...
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>포항</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>경주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>-2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>울진</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>울릉도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>5</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>5</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>제주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>8</tmn>
# 					<tmx>14</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>8</tmn>
# 					<tmx>14</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>10</tmn>
# 					<tmx>13</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>10</tmn>
# 					<tmx>13</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>서귀포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-27 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-28 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>9</tmn>
# 					<tmx>15</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-29 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>9</tmn>
# 					<tmx>15</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>11</tmn>
# 					<tmx>15</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-30 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>11</tmn>
# 					<tmx>15</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2019-12-31 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>6</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-01 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-02 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>6</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-03 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>7</tmn>
# 					<tmx>13</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %%
import sys
import urllib.request as req
import urllib.parse as parse
# 명령줄 매개변수 추출  
if len(sys.argv) <= 1:
    print("USAGE: download-forecast-argv <Region Number>")
    sys.exit()
regionNumber = sys.argv[1]
# 매개변수를 URL 인코딩합니다.  
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
values = {
    'stnId': regionNumber
}
params = parse.urlencode(values)
url = API + "?" + params
print("url=", url)
# 다운로드합니다.  
data = req.urlopen(url).read()
text = data.decode("utf-8")
print(text)
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=-f

# %%
import requests
 
# GET
resp = requests.get('http://httpbin.org/get')
print(resp.text)
 
# POST
dic = {"id": 1, "name": "Kim", "age": 10}
resp = requests.post('http://httpbin.org/post', data=dic)
print(resp.text)
 
resp = requests.put('http://httpbin.org/put')
resp = requests.delete('http://httpbin.org/delete')
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0"
#   },
#   "origin": "121.134.206.54, 121.134.206.54",
#   "url": "https://httpbin.org/get"
# }
#
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "age": "10",
#     "id": "1",
#     "name": "Kim"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "20",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0"
#   },
#   "json": null,
#   "origin": "121.134.206.54, 121.134.206.54",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests 
resp = requests.get('http://finance.naver.com/')
resp.raise_for_status() 
resp.encoding=None   # None 으로 설정
#resp.encoding='euc-kr'  # 한글 인코딩
htmls = resp.text
print(htmls)
# Out:
# <html lang="ko">
#  <head>
#   <title>네이버 금융</title>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#   <meta http-equiv="Content-Script-Type" content="text/javascript" />
#   <meta http-equiv="Content-Style-Type" content="text/css" />
#   <meta property="og:title" content="네이버 금융" />
#   <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" />
#   <meta property="og:url" content="https://finance.naver.com" />
#   <meta property="og:description" content="국내 해외 증시 지수, 시장지표, 펀드, 뉴스, 증권사 리서치 등 제공" />
#   <meta property="og:type" content="article" />
#   <meta property="og:article:thumbnailUrl" content="" />
#   <meta property="og:article:author" content="네이버금융" />
#   <meta property="og:article:author:url" content="http://FINANCE.NAVER.COM" />
#   <link rel="stylesheet" type="text/css" href="/css/finance_header.css?20191212151800" />
#   <link rel="stylesheet" type="text/css" href="/css/finance.css?20191212151800" />
#   <link rel="stylesheet" type="text/css" href="/css/newstock3.css?20191212151800" />
#   <script type="text/javascript" src="/js/jindo.min.ns.1.5.3.euckr.js?20191212151800"></script>
#   <script type="text/javascript" src="/js/release/common.js?20191212151800"></script>
#   <script type="text/javascript" src="/js/jindoComponent/jindo.Component.1.0.3.js?20191212151800"></script>
#   <script type="text/javascript" src="/ac/nhn.autocomplete.stock.js?20191212151800"></script>
#   <link rel="shortcut icon" href="https://www.naver.com/favicon.ico?20191212151800" type="image/x-icon" />
#   <script type="text/javascript">
#     (function(){
#         var sUserAgent = navigator.userAgent;
#         if(/iPhone|iPad/.test(sUserAgent)){
#             document.write(
#                 [
# 					'<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_120X120_iphone.png" />',
# 					'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_152x152_ipad.png" />',
# 					'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_167x167_ipad_pro.png" />',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static/nfinance/ico/2018_ios_180x180_iphone.png" />'
#                 ]
#                 .join('\n')
#             );
#         }
#
#         if(/Android/.test(sUserAgent)){
#             document.write(
#                 [
#                     '<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_72x72_xxxhpdi.png" />',
#                     '<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_96x96_xxxhpdi.png" />',
#                     '<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_144x144_xxxhpdi.png" />',
#                     '<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static/nfinance/ico/2018_android_192x192_xxxhpdi.png" />'
# 				]
# 				.join('\n')
# 			);
#         }
#     })();
#     </script>
#  </head>
#  <body onload="getGNB();">
#   <script type="text/javascript">
# 	document.domain = 'naver.com';
# 	var nclk_evt = 3;
# 	nclk_do();
# </script>
#   <script type="text/javascript">
#
#
#
#
#
#
#
# var nsc="finance.home";
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
# </script>
#   <div id="u_skip">
#    <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
#    <a href="#start" tabindex="2"><span>본문으로 바로가기</span></a>
#   </div>
#   <div id="header">
#    <div class="snb_area">
#     <div class="snb_inner">
#      <div id="gnb_area">
#       <div id="gnb">
#        <script charset="EUC-KR" type="text/javascript">
# 					var gnb_service = "gnbtest";
#                     var gnb_template = location.protocol == "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 					var gnb_dark = false;
# 					var gnb_brightness = 1;
# 					var gnb_logout=encodeURIComponent(location.href);
# 					var gnb_one_naver = 1;
# 					</script>
#        <script type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20191224">
#                     		</script>
#       </div>
#      </div>
#      <div class="sta">
#       <h1 class="logo"> <a href="https://www.naver.com/" class="logo_naver" onclick="clickcr(this, 'STA.naver', '', '', event);"><span class="blind">네이버</span></a> <a href="/" class="logo_service" onclick="clickcr(this, 'STA.finance', '', '', event);"><span class="blind">금융</span></a> </h1>
#       <form name="search" action="/search/search.nhn" method="get" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
#        <fieldset>
#         <legend>검색</legend>
#         <div class="snb_search_box">
#          <div class="snb_search_box_sub">
#           <input id="stock_items" type="text" title="검색" name="query" value="종목명&middot;펀드명&middot;환율명&middot;원자재명 입력" accesskey="s" class="snb_search_text snb_default" autocomplete="off" />
#           <a id="nautocomplete" href="#" onclick="return false" class="btn_arrow"><span class="blind">자동완성 펼치기</span></a>
#          </div>
#          <div class="auto_area">
#           <h2 class="blind">자동완성</h2>
#           <iframe id="autoFrame" src="/ac/reatcmp.nhn?menu=home&amp;submenu=" scrolling="no" height="0" frameborder="0" width="400" style="display: none;" marginheight="0" marginwidth="0" title="자동완성"></iframe>
#          </div>
#          <button type="submit" class="snb_search_btn" onclick="clickcr(this, 'STA.search', '', '', event);" alt="검색"><span class="blind">검색</span></button>
#          <a href="#" target="_blank" class="snb_search_btn-total" onclick="itegrationSearch();clickcr(this, 'STA.nx', '', '', event);return false;">통합검색</a>
#         </div>
#        </fieldset>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div class="lnb_area ">
#     <div class="lnb_inner">
#      <div id="menu">
#       <ul class="menu">
#        <li class="m1 first on"><a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);"><span class="tx">금융 홈</span></a></li>
#        <li class="m2 "><a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);"><span class="tx">국내증시</span></a></li>
#        <li class="m3 "><a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);"><span class="tx">해외증시</span></a></li>
#        <li class="m4 "><a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);"><span class="tx">시장지표</span></a></li>
#        <li class="m5 "><a href="/fund/" onclick="clickcr(this, 'LNB.fund', '', '', event);"><span class="tx">펀드</span></a> </li>
#        <li class="m6 "><a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);"><span class="tx">투자전략</span></a></li>
#        <li class="m7 "><a href="/news/"><span class="tx">뉴스</span></a></li>
#        <li class="m8 "><a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);"><span class="tx">MY</span></a></li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <script type="text/JavaScript">
# 		/* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.finance.naver.com";
#         if (location.hostname.indexOf("staging-") > -1) {
#             acDomain = "staging-" + acDomain;
#         }
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "jsonp", "get", {
#                     st: "111",
#                     r_lt : "111",
#                     q_enc : "euc-kr",
#                     r_enc : "euc-kr",
#                     frm: "stock"}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl : [
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"]}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		document.domain = 'naver.com';
# 		var sSearchHintText = '종목명·펀드명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = location.protocol + "//search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object)
# 		{
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
# 	</script>
#    <iframe id="me_layers" name="test" title="네이버미 영역" width="0" height="0" scrolling="no" frameborder="0" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;"></iframe>
#   </div>
#   <div id="wrap">
#    <hr />
#    <div id="start" class="blind">
#     <strong name="start">본문시작</strong>
#    </div>
#    <dl class="blind">
#     <dt>
#      오늘의 코스피/코스닥 지수
#     </dt>
#     <dd>
#      2019년 12월 24일 장중
#     </dd>
#     <dd>
#      코스피 지수 2,194.50 전일대비 하락 9.21 마이너스 0.42 퍼센트
#     </dd>
#     <dd>
#      코스닥 지수 640.93 전일대비 하락 6.69 마이너스 1.03 퍼센트
#     </dd>
#    </dl>
#    <div class="home_spot view_on">
#     <div class="bx_spot">
#      <div class="tab_spot tab2" id="tab_search">
#       <ul>
#        <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab1', '000000', 'recent');clickcr(this, 'mys.recent', '', '', event);return false;"><span>최근조회종목</span></a></li>
#        <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab2', '000000', 'mystock');clickcr(this, 'mys.interest', '', '', event);return false;"><span>MY STOCK</span></a></li>
#       </ul>
#      </div>
#      <div class="section_tab" id="recent_search_tab">
#       <strong class="blind" id="recent_mystock_blind">최근 조회종목 리스트</strong>
#       <ul class="tab_list">
#       </ul>
#      </div>
#      <input type="image" src="https://ssl.pstatic.net/static/nfinance/btn_spot_close.gif" class="btn_spot" alt="닫기" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.close' : 'mys*i.close'), '', '', event);" style="display:none" />
#      <input type="image" src="https://ssl.pstatic.net/static/nfinance/btn_spot_open.gif" class="btn_spot" alt="펼치기" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.open' : 'mys*i.open'), '', '', event);" style="display:none" />
#     </div>
#    </div>
#    <div id="container" class="home">
#     <div id="content">
#      <div class="article">
#       <div class="section">
#        <div class="news_area">
#         <div class="section_strategy">
#          <h2 class="h_strategy"><span>주요뉴스</span></h2>
#          <ul>
#           <li> <span><a href="/news/news_read.nhn?mode=mainnews&amp;office_id=008&amp;article_id=0004329730" onclick="clickcr(this, 'tdn.list', '008_0004329730', '0', event);">[Asia오전]&quot;투자자들도 크리스마스 휴가&quot; 혼조세</a></span> </li>
#           <li> <span><a href="/news/news_read.nhn?mode=mainnews&amp;office_id=015&amp;article_id=0004262242" onclick="clickcr(this, 'tdn.list', '015_0004262242', '1', event);">[김현석의 월스트리트나우] 월가가 '1998년'을 돌아보는 이유</a></span> </li>
#           <li> <span><a href="/news/news_read.nhn?mode=mainnews&amp;office_id=011&amp;article_id=0003670653" onclick="clickcr(this, 'tdn.list', '011_0003670653', '2', event);">[오전시황]연말 앞두고 보합세...코스피 2,200선 유지</a></span> </li>
#           <li> <span><a href="/news/news_read.nhn?mode=mainnews&amp;office_id=018&amp;article_id=0004542599" onclick="clickcr(this, 'tdn.list', '018_0004542599', '3', event);">[외환브리핑]中수입관세 인하…원&middot;달러 환율 영향은</a></span> </li>
#           <li> <span><a href="/news/news_read.nhn?mode=mainnews&amp;office_id=277&amp;article_id=0004594504" onclick="clickcr(this, 'tdn.list', '277_0004594504', '4', event);">[굿모닝 증시] 온기 도는 연말연초 주식시장</a></span> </li>
#           <li> <span><a href="/news/news_read.nhn?mode=mainnews&amp;office_id=008&amp;article_id=0004329562" onclick="clickcr(this, 'tdn.list', '008_0004329562', '5', event);">中 관세인하에 美 증시 '최고치'…&quot;韓, 특별한 이벤트 부재&quot;</a></span> </li>
#          </ul>
#          <a href="/news/mainnews.nhn" class="btn_more" onclick="clickcr(this, 'tdn.more', '', '', event);"><em class="btn_more4"><span class="blind">주요뉴스 더보기</span></em></a>
#         </div>
#        </div>
#        <div class="section_sise_top">
#         <h2 class="h_type"><span>TOP 종목</span></h2>
#         <ul class="tab_area sise_top1">
#          <li class="tab1"><a href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;" class="is_active"><span>거래상위</span></a></li>
#          <li class="tab2"><a href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span>상한가</span></a></li>
#          <li class="tab3"><a href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span>하한가</span></a></li>
#          <li class="tab4"><a href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span>시가총액 상위</span></a></li>
#         </ul>
#         <div class="group_type is_active">
#          <table class="tbl_home">
#           <caption>
#            거래상위 TOP 종목
#            <span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span>
#           </caption>
#           <colgroup>
#            <col width="40%" />
#            <col />
#           </colgroup>
#           <thead>
#            <tr>
#             <th scope="col">종목명</th>
#             <th scope="col">현재가</th>
#             <th scope="col">전일대비</th>
#             <th scope="col">등락률</th>
#            </tr>
#           </thead>
#           <tbody id="_topItems1">
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=025560" onclick="clickcr(this, 'spe.slist', '025560', '1', event);">미래산업</a></th>
#             <td>126</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 15</td>
#             <td> <em class="down"> -10.64% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=052190" onclick="clickcr(this, 'spe.slist', '052190', '2', event);">이에스에이</a></th>
#             <td>1,400</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 575</td>
#             <td> <em class="down"> -29.11% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=009810" onclick="clickcr(this, 'spe.slist', '009810', '3', event);">엔케이물산</a></th>
#             <td>1,045</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 445</td>
#             <td> <em class="down"> -29.87% </em> </td>
#            </tr>
#            <tr class="up">
#             <th scope="row"><a href="/item/main.nhn?code=004100" onclick="clickcr(this, 'spe.slist', '004100', '4', event);">태양금속</a></th>
#             <td>1,405</td>
#             <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 75</td>
#             <td> <em class="up"> +5.64% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=044380" onclick="clickcr(this, 'spe.slist', '044380', '5', event);">주연테크</a></th>
#             <td>802</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 1</td>
#             <td> <em class="down"> -0.12% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=082800" onclick="clickcr(this, 'spe.slist', '082800', '6', event);">루미마이크로</a></th>
#             <td>1,680</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 550</td>
#             <td> <em class="down"> -24.66% </em> </td>
#            </tr>
#           </tbody>
#          </table>
#          <a href="/sise/sise_quant.nhn" class="btn_more" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
#         </div>
#         <div class="group_type">
#          <table class="tbl_home">
#           <caption>
#            상한가 TOP 종목
#            <span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span>
#           </caption>
#           <colgroup>
#            <col width="40%" />
#            <col />
#           </colgroup>
#           <thead>
#            <tr>
#             <th scope="col">종목명</th>
#             <th scope="col">현재가</th>
#             <th scope="col">전일대비</th>
#             <th scope="col">등락률</th>
#            </tr>
#           </thead>
#           <tbody id="_topItems2">
#            <tr class="up">
#             <th scope="row"><a href="/item/main.nhn?code=086250" onclick="clickcr(this, 'spe.clist', '086250', '1', event);">화신테크</a></th>
#             <td>3,435</td>
#             <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 790</td>
#             <td> <em class="up"> +29.87% </em> </td>
#            </tr>
#            <tr class="up">
#             <th scope="row"><a href="/item/main.nhn?code=18064K" onclick="clickcr(this, 'spe.clist', '18064K', '2', event);">한진칼우</a></th>
#             <td>61,200</td>
#             <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 14,100</td>
#             <td> <em class="up"> +29.94% </em> </td>
#            </tr>
#            <tr class="up">
#             <th scope="row"><a href="/item/main.nhn?code=327260" onclick="clickcr(this, 'spe.clist', '327260', '3', event);">메탈라이프</a></th>
#             <td>33,800</td>
#             <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 7,800</td>
#             <td> <em class="up"> +30.00% </em> </td>
#            </tr>
#           </tbody>
#          </table>
#          <a href="/sise/sise_upper.nhn" class="btn_more" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상한가 더보기</span></em></a>
#         </div>
#         <div class="group_type">
#          <table class="tbl_home">
#           <caption>
#            하한가 TOP 종목
#            <span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span>
#           </caption>
#           <colgroup>
#            <col width="40%" />
#            <col />
#           </colgroup>
#           <thead>
#            <tr>
#             <th scope="col">종목명</th>
#             <th scope="col">현재가</th>
#             <th scope="col">전일대비</th>
#             <th scope="col">등락률</th>
#            </tr>
#           </thead>
#           <tbody id="_topItems3">
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=009810" onclick="clickcr(this, 'spe.blist', '009810', '1', event);">엔케이물산</a></th>
#             <td>1,045</td>
#             <td><em class="bu_p bu_pdn2"><span class="blind">하한가</span></em> -445</td>
#             <td> <em class="down"> -29.87% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=041910" onclick="clickcr(this, 'spe.blist', '041910', '2', event);">에스텍파마</a></th>
#             <td>12,200</td>
#             <td><em class="bu_p bu_pdn2"><span class="blind">하한가</span></em> -5,200</td>
#             <td> <em class="down"> -29.89% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=200230" onclick="clickcr(this, 'spe.blist', '200230', '3', event);">텔콘RF제약</a></th>
#             <td>5,460</td>
#             <td><em class="bu_p bu_pdn2"><span class="blind">하한가</span></em> -2,330</td>
#             <td> <em class="down"> -29.91% </em> </td>
#            </tr>
#           </tbody>
#          </table>
#          <a href="/sise/sise_lower.nhn" class="btn_more" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">하한가 더보기</span></em></a>
#         </div>
#         <div class="group_type">
#          <table class="tbl_home">
#           <caption>
#            시가총액 상위 TOP 종목
#            <span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span>
#           </caption>
#           <colgroup>
#            <col />
#            <col width="40%" />
#            <col />
#           </colgroup>
#           <thead>
#            <tr>
#             <th scope="col">종목명</th>
#             <th scope="col">현재가</th>
#             <th scope="col">전일대비</th>
#             <th scope="col">등락률</th>
#            </tr>
#           </thead>
#           <tbody id="_topItems4">
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=005930" onclick="clickcr(this, 'spe.vlist', '005930', '1', event);">삼성전자</a></th>
#             <td>55,000</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 500</td>
#             <td> <em class="down"> -0.90% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=000660" onclick="clickcr(this, 'spe.vlist', '000660', '2', event);">SK하이닉스</a></th>
#             <td>94,200</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 400</td>
#             <td> <em class="down"> -0.42% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=005935" onclick="clickcr(this, 'spe.vlist', '005935', '3', event);">삼성전자우</a></th>
#             <td>44,950</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 150</td>
#             <td> <em class="down"> -0.33% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=035420" onclick="clickcr(this, 'spe.vlist', '035420', '4', event);">NAVER</a></th>
#             <td>182,000</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 2,000</td>
#             <td> <em class="down"> -1.09% </em> </td>
#            </tr>
#            <tr class="up">
#             <th scope="row"><a href="/item/main.nhn?code=207940" onclick="clickcr(this, 'spe.vlist', '207940', '5', event);">삼성바이오로직스</a></th>
#             <td>423,500</td>
#             <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,000</td>
#             <td> <em class="up"> +0.24% </em> </td>
#            </tr>
#            <tr class="down">
#             <th scope="row"><a href="/item/main.nhn?code=005380" onclick="clickcr(this, 'spe.vlist', '005380', '6', event);">현대차</a></th>
#             <td>122,000</td>
#             <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 500</td>
#             <td> <em class="down"> -0.41% </em> </td>
#            </tr>
#           </tbody>
#          </table>
#          <a href="/sise/sise_market_sum.nhn" class="btn_more" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">시가총액 상위 더보기</span></em></a>
#         </div>
#        </div>
#        <div class="section_rate">
#         <h2 class="h_rate"><span>수익률 상위펀드</span></h2>
#         <p class="dec_rate">3개월수익률 순 <span class="bar">|</span> <em>2019.12.24</em>기준</p>
#         <ul class="tab_rate rate1">
#          <li class="tab1"><a href="#" onclick="clickcr(this, 'tfd.ctab', '', '', event);return false;"><span>국내펀드</span></a></li>
#          <li class="tab2"><a href="#" onclick="clickcr(this, 'tfd.wtab', '', '', event);return false;"><span>해외펀드</span></a></li>
#          <li class="tab3"><a href="#" onclick="clickcr(this, 'tfd.1tab', '', '', event);return false;"><span>브릭스</span></a></li>
#          <li class="tab4"><a href="#" onclick="clickcr(this, 'tfd.2tab', '', '', event);return false;"><span>삼성그룹주</span></a></li>
#         </ul>
#         <div class="rate_list rate_on">
#          <h3 class="blind">국내펀드</h3>
#          <ol>
#           <li class="num1"><span class="info_num info_num1"><span class="blind">1</span></span><a href="/fund/fundDetail.nhn?fundCd=K55301BD4689" onclick="clickcr(this, 'tfd.clist', 'K55301BD4689', '1', event);"><strong>미래에셋TIGER200IT레버리지증권상장지수투자신탁(주식-..</strong></a></li>
#           <li class="num2"><span class="info_num info_num2"><span class="blind">2</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5105578185" onclick="clickcr(this, 'tfd.clist', 'KR5105578185', '2', event);">삼성KODEX반도체증권상장지수투자신탁[주식]</a></li>
#           <li class="num3"><span class="info_num info_num3"><span class="blind">3</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5225578230" onclick="clickcr(this, 'tfd.clist', 'KR5225578230', '3', event);">미래에셋TIGER반도체증권상장지수투자신탁(주식)</a></li>
#           <li class="num4"><span class="info_num info_num4"><span class="blind">4</span></span><a href="/fund/fundDetail.nhn?fundCd=K55105C75384" onclick="clickcr(this, 'tfd.clist', 'K55105C75384', '4', event);">삼성KODEX한국대만IT프리미어증권상장지수투자신탁[주식..</a></li>
#           <li class="num5"><span class="info_num info_num5"><span class="blind">5</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5103972976" onclick="clickcr(this, 'tfd.clist', 'KR5103972976', '5', event);">한화2.2배레버리지인덱스증권투자신탁(주식-파생재간접..</a></li>
#          </ol>
#          <a href="/fund/fund.nhn" class="btn_more" onclick="clickcr(this, 'tfd.more', '', '', event);"><em class="btn_more4"><span class="blind">국내펀드 더보기</span></em></a>
#         </div>
#         <div class="rate_list">
#          <h3 class="blind">해외펀드</h3>
#          <ol>
#           <li class="num1"><span class="info_num info_num1"><span class="blind">1</span></span><a href="/fund/fundDetail.nhn?fundCd=K55301B96890" onclick="clickcr(this, 'tfd.wlist', 'K55301B96890', '1', event);"><strong>미래에셋TIGER인도레버리지증권상장지수투자신탁(주식혼..</strong></a></li>
#           <li class="num2"><span class="info_num info_num2"><span class="blind">2</span></span><a href="/fund/fundDetail.nhn?fundCd=K55223CV8484" onclick="clickcr(this, 'tfd.wlist', 'K55223CV8484', '2', event);">KBKBSTAR팔라듐선물특별자산상장지수투자신탁(파생형)(H..</a></li>
#           <li class="num3"><span class="info_num info_num3"><span class="blind">3</span></span><a href="/fund/fundDetail.nhn?fundCd=K55301B52703" onclick="clickcr(this, 'tfd.wlist', 'K55301B52703', '3', event);">미래에셋TIGERMSCIEM레버리지증권상장지수투자신탁(주식..</a></li>
#           <li class="num4"><span class="info_num info_num4"><span class="blind">4</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5223AS5257" onclick="clickcr(this, 'tfd.wlist', 'KR5223AS5257', '4', event);">KBKBSTAR일본TOPIX레버리지증권상장지수투자신탁(주식-..</a></li>
#           <li class="num5"><span class="info_num info_num5"><span class="blind">5</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5101AR9802" onclick="clickcr(this, 'tfd.wlist', 'KR5101AR9802', '5', event);">한국투자KINDEX일본레버리지증권상장지수투자신탁(주식-..</a></li>
#          </ol>
#          <a href="/fund/worldFund.nhn" class="btn_more" onclick="clickcr(this, 'tfd.more', '', '', event);"><em class="btn_more4"><span class="blind">해외펀드 더보기</span></em></a>
#         </div>
#         <div class="rate_list">
#          <h3 class="blind">브릭스</h3>
#          <ol>
#           <li class="num1"><span class="info_num info_num1"><span class="blind">1</span></span><a href="/fund/fundDetail.nhn?fundCd=K55301B43363" onclick="clickcr(this, 'tfd.1list', 'K55301B43363', '1', event);"><strong>미래에셋연금브라질업종대표증권자투자신탁 1(주식)종류..</strong></a></li>
#           <li class="num2"><span class="info_num info_num2"><span class="blind">2</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5301767863" onclick="clickcr(this, 'tfd.1list', 'KR5301767863', '2', event);">미래에셋브라질업종대표증권자투자신탁 1(주식)종류A</a></li>
#           <li class="num3"><span class="info_num info_num3"><span class="blind">3</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5225730104" onclick="clickcr(this, 'tfd.1list', 'KR5225730104', '3', event);">미래에셋e-오션브릭스인덱스증권자투자신탁 1(주식)종류..</a></li>
#           <li class="num4"><span class="info_num info_num4"><span class="blind">4</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5101AQ4572" onclick="clickcr(this, 'tfd.1list', 'KR5101AQ4572', '4', event);">한국투자골드플랜브릭스연금증권전환형자투자신탁 1(주..</a></li>
#           <li class="num5"><span class="info_num info_num5"><span class="blind">5</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5101856379" onclick="clickcr(this, 'tfd.1list', 'KR5101856379', '5', event);">한국투자신종개인연금브릭스증권전환형자투자신탁 1(주..</a></li>
#          </ol>
#          <a href="/fund/themeFund.nhn?search=W120" class="btn_more" onclick="clickcr(this, 'tfd.more', '', '', event);"><em class="btn_more4"><span class="blind">브릭스 더보기</span></em></a>
#         </div>
#         <div class="rate_list">
#          <h3 class="blind">삼성그룹주</h3>
#          <ol>
#           <li class="num1"><span class="info_num info_num1"><span class="blind">1</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5225A01840" onclick="clickcr(this, 'tfd.2list', 'KR5225A01840', '1', event);"><strong>미래에셋TIGER삼성그룹증권상장지수투자신탁(주식)</strong></a></li>
#           <li class="num2"><span class="info_num info_num2"><span class="blind">2</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5101897761" onclick="clickcr(this, 'tfd.2list', 'KR5101897761', '2', event);">한국투자KINDEX삼성그룹주SW 증권상장지수투자신탁(주식..</a></li>
#           <li class="num3"><span class="info_num info_num3"><span class="blind">3</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5105834570" onclick="clickcr(this, 'tfd.2list', 'KR5105834570', '3', event);">삼성KODEX삼성그룹주증권상장지수투자신탁[주식]</a></li>
#           <li class="num4"><span class="info_num info_num4"><span class="blind">4</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5105AY4057" onclick="clickcr(this, 'tfd.2list', 'KR5105AY4057', '4', event);">삼성KODEX삼성그룹밸류증권상장지수투자신탁[주식]</a></li>
#           <li class="num5"><span class="info_num info_num5"><span class="blind">5</span></span><a href="/fund/fundDetail.nhn?fundCd=KR5101299273" onclick="clickcr(this, 'tfd.2list', 'KR5101299273', '5', event);">한국투자KINDEX삼성그룹주동일가중증권상장지수투자신탁..</a></li>
#          </ol>
#          <a href="/fund/themeFund.nhn?search=N101" class="btn_more" onclick="clickcr(this, 'tfd.more', '', '', event);"><em class="btn_more4"><span class="blind">삼성그룹주 더보기</span></em></a>
#         </div>
#        </div>
#       </div>
#       <div class="section2">
#        <div class="section_stock_market">
#         <div class="group_heading">
#          <h2 class="h_market"><span>오늘의 증시</span></h2>
#          <div class="ly_realtime">
#           <span href="#" class="btn_realtime"> <span class="blind">실시간</span> <span class="ly_help">실시간으로 지수 <br />데이터를 제공 중입니다.</span> </span>
#           <span id="time"> 2019.12.24 14:34<span>장중</span> </span>
#          </div>
#         </div>
#         <div class="section_stock">
#          <div class="kospi_area group_quot quot_opn" style="height:269px">
#           <div class="heading_area">
#            <h4 class="h_opn"><a href="/sise/sise_index.nhn?code=KOSPI" onclick="clickcr(this, 'tsc*k.title', '', '', event);" title="코스피지수 상세보기" class="_stock_section"><em><span class="blind">코스피</span></em></a></h4>
#            <a href="/sise/sise_index.nhn?code=KOSPI" onclick="clickcr(this, 'tsc*k.title', '', '', event);" title="코스피지수 상세보기"> <span class="num_quot dn"> <span class="num">2,194.50</span> <span class="num2">9.21</span> <span class="num3"><span class="blind">-</span>0.42<span class="per">%</span></span> <span class="blind">하락</span> </span> </a>
#            <span class="clse_bg"></span>
#           </div>
#           <div class="chart_area">
#            <p class="blind">코스피 시세 차트</p>
#            <a href="/sise/sise_index.nhn?code=KOSPI" onclick="clickcr(this, 'tsc*k.chart', '', '', event);" title="코스피지수 상세보기"><img src="https://ssl.pstatic.net/imgfinance/chart/main/KOSPI.png?sidcode=1577165641460" width="301" height="127" alt="지수" /></a>
#           </div>
#           <div class="dsc_area">
#            <dl class="dl">
#             <dt>
#              <a href="/sise/sise_trans_style.nhn?sosok=01" onclick="clickcr(this, 'tsc*k.private', '', '', event);" title="투자자별 매매 동향 상세보기">개인</a>
#             </dt>
#             <dd class="dn">
#              <a href="/sise/sise_trans_style.nhn?sosok=01" onclick="clickcr(this, 'tsc*k.private', '', '', event);">-160</a>
#              <span class="blind">억원</span>
#             </dd>
#             <dt>
#              <a href="/sise/sise_trans_style.nhn?sosok=01" onclick="clickcr(this, 'tsc*k.foreign', '', '', event);" title="투자자별 매매 동향 상세보기">외국인</a>
#             </dt>
#             <dd class="dn">
#              <a href="/sise/sise_trans_style.nhn?sosok=01" onclick="clickcr(this, 'tsc*k.foreign', '', '', event);">-1,281</a>
#              <span class="blind">억원</span>
#             </dd>
#             <dt>
#              <a href="/sise/sise_trans_style.nhn?sosok=01" onclick="clickcr(this, 'tsc*k.institutional', '', '', event);" title="투자자별 매매 동향 상세보기">기관</a>
#             </dt>
#             <dd class="up">
#              <a href="/sise/sise_trans_style.nhn?sosok=01" onclick="clickcr(this, 'tsc*k.institutional', '', '', event);">+1,344</a>
#              <span class="blind">억원</span>
#             </dd>
#            </dl>
#            <dl class="dl2">
#             <dt class="blind">
#              상한종목수
#             </dt>
#             <dd class="dd">
#              <a href="/sise/sise_upper.nhn" onclick="clickcr(this, 'tsc*k.ceiling', '', '', event);" title="상한종목 상세보기">1</a>
#             </dd>
#             <dt class="blind">
#              상승종목수
#             </dt>
#             <dd class="dd2">
#              <a href="/sise/sise_rise.nhn?sosok=0" onclick="clickcr(this, 'tsc*k.rise', '', '', event);" title="상승종목 상세보기">323</a>
#             </dd>
#             <dt class="blind">
#              보합종목수
#             </dt>
#             <dd class="dd3">
#              <a href="/sise/sise_steady.nhn?sosok=0" onclick="clickcr(this, 'tsc*k.steady', '', '', event);" title="보합종목 상세보기">69</a>
#             </dd>
#             <dt class="blind">
#              하락종목수
#             </dt>
#             <dd class="dd4">
#              <a href="/sise/sise_fall.nhn?sosok=0" onclick="clickcr(this, 'tsc*k.drop', '', '', event);" title="하락종목 상세보기">515</a>
#             </dd>
#             <dt class="blind">
#              하한종목수
#             </dt>
#             <dd class="dd5">
#              <a href="/sise/sise_lower.nhn" onclick="clickcr(this, 'tsc*k.floor', '', '', event);" title="하한종목 상세보기">1</a>
#             </dd>
#            </dl>
#           </div>
#          </div>
#          <div class="kosdaq_area group_quot" style="height:40px">
#           <div class="heading_area">
#            <h4><a href="/sise/sise_index.nhn?code=KOSDAQ" onclick="clickcr(this, 'tsc*q.title', '', '', event);" title="코스닥지수 상세보기" class="_stock_section"><em><span class="blind">코스닥</span></em></a></h4>
#            <a href="/sise/sise_index.nhn?code=KOSDAQ" onclick="clickcr(this, 'tsc*q.title', '', '', event);" title="코스닥지수 상세보기"> <span class="num_quot dn"> <span class="num">640.93</span> <span class="num2">6.69</span> <span class="num3"><span class="blind">-</span>1.03<span class="per">%</span></span> <span class="blind">하락</span> </span> </a>
#            <span class="clse_bg"></span>
#           </div>
#           <div class="chart_area">
#            <p class="blind">코스닥 시세 차트</p>
#            <a href="/sise/sise_index.nhn?code=KOSDAQ" onclick="clickcr(this, 'tsc*q.chart', '', '', event);" title="코스닥지수 상세보기"><img src="https://ssl.pstatic.net/imgfinance/chart/main/KOSDAQ.png?sidcode=1577165641461" width="301" height="127" alt="지수" /></a>
#           </div>
#           <div class="dsc_area">
#            <dl class="dl">
#             <dt>
#              <a href="/sise/sise_trans_style.nhn?sosok=02" onclick="clickcr(this, 'tsc*q.private', '', '', event);" title="투자자별 매매 동향 상세보기">개인</a>
#             </dt>
#             <dd class="dn">
#              <a href="/sise/sise_trans_style.nhn?sosok=02" onclick="clickcr(this, 'tsc*q.private', '', '', event);">-115</a>
#              <span class="blind">억원</span>
#             </dd>
#             <dt>
#              <a href="/sise/sise_trans_style.nhn?sosok=02" onclick="clickcr(this, 'tsc*q.foreign', '', '', event);" title="투자자별 매매 동향 상세보기">외국인</a>
#             </dt>
#             <dd class="up">
#              <a href="/sise/sise_trans_style.nhn?sosok=02" onclick="clickcr(this, 'tsc*q.foreign', '', '', event);">+38</a>
#              <span class="blind">억원</span>
#             </dd>
#             <dt>
#              <a href="/sise/sise_trans_style.nhn?sosok=02" onclick="clickcr(this, 'tsc*q.institutional', '', '', event);" title="투자자별 매매 동향 상세보기">기관</a>
#             </dt>
#             <dd class="up">
#              <a href="/sise/sise_trans_style.nhn?sosok=02" onclick="clickcr(this, 'tsc*q.institutional', '', '', event);">+242</a>
#              <span class="blind">억원</span>
#             </dd>
#            </dl>
#            <dl class="dl2">
#             <dt class="blind">
#              상한종목수
#             </dt>
#             <dd class="dd">
#              <a href="/sise/sise_upper.nhn" onclick="clickcr(this, 'tsc*q.ceiling', '', '', event);" title="상한종목 상세보기">2</a>
#             </dd>
#             <dt class="blind">
#              상승종목수
#             </dt>
#             <dd class="dd2">
#              <a href="/sise/sise_rise.nhn?sosok=1" onclick="clickcr(this, 'tsc*q.rise', '', '', event);" title="상승종목 상세보기">328</a>
#             </dd>
#             <dt class="blind">
#              보합종목수
#             </dt>
#             <dd class="dd3">
#              <a href="/sise/sise_steady.nhn?sosok=1" onclick="clickcr(this, 'tsc*q.steady', '', '', event);" title="보합종목 상세보기">104</a>
#             </dd>
#             <dt class="blind">
#              하락종목수
#             </dt>
#             <dd class="dd4">
#              <a href="/sise/sise_fall.nhn?sosok=1" onclick="clickcr(this, 'tsc*q.drop', '', '', event);" title="하락종목 상세보기">914</a>
#             </dd>
#             <dt class="blind">
#              하한종목수
#             </dt>
#             <dd class="dd5">
#              <a href="/sise/sise_lower.nhn" onclick="clickcr(this, 'tsc*q.floor', '', '', event);" title="하한종목 상세보기">2</a>
#             </dd>
#            </dl>
#           </div>
#          </div>
#          <div class="kospi200_area group_quot" style="height:40px">
#           <div class="heading_area">
#            <h4><a href="/sise/sise_index.nhn?code=KPI200" onclick="clickcr(this, 'tsc*f.title', '', '', event);" title="코스피200지수 상세보기" class="_stock_section"><em><span class="blind">코스피200</span></em></a></h4>
#            <a href="/sise/sise_index.nhn?code=KPI200" onclick="clickcr(this,'tsc*o.title','','',event);" title="코스피200지수 상세보기"> <span class="num_quot dn"> <span class="num">293.39</span> <span class="num2">1.48</span> <span class="num3"><span class="blind">-</span>0.50<span class="per">%</span></span> <span class="blind">하락</span> </span> </a>
#            <span class="clse_bg"></span>
#           </div>
#           <div class="chart_area">
#            <p class="blind">코스피200 시세 차트</p>
#            <a href="/sise/sise_index.nhn?code=KPI200" onclick="clickcr(this,'tsc*o.chart','','',event);" title="코스피200지수 상세보기"><img src="https://ssl.pstatic.net/imgfinance/chart/main/KPI200.png?sidcode=1577165641463" width="301" height="127" alt="지수" /></a>
#           </div>
#           <div class="dsc_area dsc_area2">
#            <dl class="dl">
#             <dt>
#              개인
#             </dt>
#             <dd class="dn">
#              -797
#              <span class="blind">억원</span>
#             </dd>
#             <dt>
#              외국인
#             </dt>
#             <dd class="dn">
#              -1,048
#              <span class="blind">억원</span>
#             </dd>
#             <dt>
#              기관
#             </dt>
#             <dd class="up">
#              +1,736
#              <span class="blind">억원</span>
#             </dd>
#            </dl>
#           </div>
#           <div class="basis_area">
#            <dl>
#             <dt class="dt">
#              <a href="/sise/sise_program.nhn?sosok=01" title="프로그램매매 동향 상세보기"><span class="blind">프로그램</span></a>
#             </dt>
#             <dd class="dd2 dn" id="_kospiProgram">
#              <a href="/sise/sise_program.nhn?sosok=01" onclick="clickcr(this,'tsc*o.program','','',event);" title="프로그램매매 동향 상세보기">-1,144<span>억</span></a>
#             </dd>
#             <dt id="basis_name" class="blind">
#              베이시스
#             </dt>
#             <dd id="basis_value" class="dd dn">
#              <span>-2.99 <img src="https://ssl.pstatic.net/imgfinance/finance/btn_backwar.gif" width="49" height="17" alt="백워데이션" /> </span>
#             </dd>
#            </dl>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="section_top section_top_first">
#         <h2 class="h_top"><span>업종상위</span></h2>
#         <ul class="list_rank">
#          <li class="ranking1"> <span class="info_num info_num1"><span class="blind">1</span></span> <p class="item"> <a href="/sise/sise_group_detail.nhn?type=upjong&amp;no=205" onclick="clickcr(this, 'tos.cat1', 'upjong_205', '', event);"><strong>에너지장비및서..</strong></a> <em class="up"> +4.09% </em> </p> <p> <a href="/item/main.nhn?code=137950" onclick="clickcr(this, 'tos.list1', '137950', '1', event);">제이씨케미칼</a> <em class="up"> +23.53% </em> </p> <p> <a href="/item/main.nhn?code=099220" onclick="clickcr(this, 'tos.list1', '099220', '2', event);">SDN</a> <em class="up"> +3.51% </em> </p> </li>
#          <li class="ranking2"> <span class="info_num info_num2"><span class="blind">2</span></span> <p class="item"> <a href="/sise/sise_group_detail.nhn?type=upjong&amp;no=189" onclick="clickcr(this, 'tos.cat2', 'upjong_189', '', event);"><strong>운송인프라</strong></a> <em class="up"> +1.05% </em> </p> <p> <a href="/item/main.nhn?code=005430" onclick="clickcr(this, 'tos.list2', '005430', '1', event);">한국공항</a> <em class="up"> +2.74% </em> </p> <p> <a href="/item/main.nhn?code=045340" onclick="clickcr(this, 'tos.list2', '045340', '2', event);">토탈소프트</a> <em class="steady"> 0.00% </em> </p> </li>
#          <li class="ranking3"> <span class="info_num info_num3"><span class="blind">3</span></span> <p class="item"> <a href="/sise/sise_group_detail.nhn?type=upjong&amp;no=145" onclick="clickcr(this, 'tos.cat3', 'upjong_145', '', event);"><strong>음료</strong></a> <em class="up"> +0.73% </em> </p> <p> <a href="/item/main.nhn?code=023150" onclick="clickcr(this, 'tos.list3', '023150', '1', event);">MH에탄올</a> <em class="up"> +1.96% </em> </p> <p> <a href="/item/main.nhn?code=000145" onclick="clickcr(this, 'tos.list3', '000145', '2', event);">하이트진로홀..</a> <em class="up"> +1.62% </em> </p> </li>
#         </ul>
#         <a href="/sise/sise_group.nhn?type=upjong" class="btn_more" onclick="clickcr(this, 'tos.more', '', '', event);"><em class="btn_more4"><span class="blind">업종상위 더보기</span></em></a>
#        </div>
#        <div class="section_top group_top">
#         <h2 class="h_theme"><span>테마상위</span></h2>
#         <ul class="list_rank">
#          <li class="ranking1"> <span class="info_num info_num1"><span class="blind">1</span></span> <p class="item"> <a href="/sise/sise_group_detail.nhn?type=theme&amp;no=400" onclick="clickcr(this, 'pol.type1', 'thema_400', '', event);"><strong>조림사업</strong></a> <em class="up"> +1.75% </em> </p> <p> <a href="/item/main.nhn?code=137950" onclick="clickcr(this, 'pol.list1', '137950', '1', event);"> 제이씨케미.. </a> <em class="up"> +23.53% </em> </p> <p> <a href="/item/main.nhn?code=043910" onclick="clickcr(this, 'pol.list1', '043910', '2', event);"> 자연과환경 </a> <em class="up"> +2.46% </em> </p> </li>
#          <li class="ranking2"> <span class="info_num info_num2"><span class="blind">2</span></span> <p class="item"> <a href="/sise/sise_group_detail.nhn?type=theme&amp;no=213" onclick="clickcr(this, 'pol.type2', 'thema_213', '', event);"><strong>해저터널</strong></a> <em class="up"> +1.35% </em> </p> <p> <a href="/item/main.nhn?code=060370" onclick="clickcr(this, 'pol.list2', '060370', '1', event);"> KT서브마린 </a> <em class="up"> +4.90% </em> </p> <p> <a href="/item/main.nhn?code=028100" onclick="clickcr(this, 'pol.list2', '028100', '2', event);"> 동아지질 </a> <em class="up"> +1.93% </em> </p> </li>
#          <li class="ranking3"> <span class="info_num info_num3"><span class="blind">3</span></span> <p class="item"> <a href="/sise/sise_group_detail.nhn?type=theme&amp;no=298" onclick="clickcr(this, 'pol.type3', 'thema_298', '', event);"><strong>희귀금속(희토류..</strong></a> <em class="up"> +1.30% </em> </p> <p> <a href="/item/main.nhn?code=087730" onclick="clickcr(this, 'pol.list3', '087730', '1', event);"> 에스모 머티.. </a> <em class="up"> +24.55% </em> </p> <p> <a href="/item/main.nhn?code=081150" onclick="clickcr(this, 'pol.list3', '081150', '2', event);"> 티플랙스 </a> <em class="up"> +0.66% </em> </p> </li>
#         </ul>
#         <a href="/sise/theme.nhn" class="btn_more" onclick="clickcr(this, 'pol.more', '', '', event);"><em class="btn_more4"><span class="blind">테마상위 더보기</span></em></a>
#        </div>
#       </div>
#      </div>
#      <div class="article2">
#       <div class="section1">
#        <div class="group1">
#         <h2 class="h_exchange"><span>환전 고시 환율</span></h2>
#         <table class="tbl_home">
#          <caption>
#           환전 고시 환율
#           <span>통화명에 대한 현재가,전일대비로 구분되어 있습니다.</span>
#          </caption>
#          <colgroup>
#           <col />
#           <col width="50" />
#           <col width="50" />
#          </colgroup>
#          <thead>
#           <tr>
#            <th scope="col">구분</th>
#            <th scope="col">현재가</th>
#            <th scope="col">전일대비</th>
#           </tr>
#          </thead>
#          <tbody>
#           <tr class="down bold">
#            <th scope="row"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'exr.list', 'FX_USDKRW', '1', event);">미국USD</a></th>
#            <td>1,163.50</td>
#            <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 0.50</td>
#           </tr>
#           <tr class="down">
#            <th scope="row"><a href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'exr.list', 'FX_JPYKRW', '2', event);">일본JPY (100엔)</a></th>
#            <td>1,063.48</td>
#            <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 0.46</td>
#           </tr>
# ...
# }
#
# var clearInformationTimer = function() {
# 	if (oUpdateAjax) {
# 		oUpdateAjax.abort();
# 		oUpdateAjax = null;
# 	}
#
# 	informationTimer = window.clearInterval(informationTimer);
# }
#
# var doUpdateInformation = function() {
# 	var sApiUrl = "https://api.finance.naver.com/service/mainSummary.nhn";
#
# 	oUpdateAjax = jindo.$Ajax(sApiUrl, {
# 		type : "jsonp",
# 		jsonp_charset : "utf-8",
# 		onload : function(oRes) {
# 			if(oRes != null && oRes.readyState() == 4) {
# 				var result = oRes.json().message.result;
# 				if(result != null) {
# 					var todayIndexDealTrendList = result.todayIndexDealTrendList; // 투자매매동향
# 					var todayIndexItemList = result.todayIndexItemList; // 등락종목 개수
# 					var kospiTrendProgram = result.kospiTrendProgram; // 프로그램
# 					var groupTopList = result.groupTopList; // 업종상위
# 					var themeTopList = result.themeTopList; // 테마상위
# 					var topItems = result.topItems; // TOP종목 (거래상위, 상한가, 하한가, 시가총액상위)
# 					var searchList = result.searchList; // 인기 검색 종목
#
# 					// 오늘의 증시 코스피, 코스닥 투자매매동향 등락종목 개수
# 					jindo.$A(jindo.$$(".dsc_area")).forEach(function(value, index) {
# 						if ( index < 2 ) {
# 							var todayIndexDealTrend = todayIndexDealTrendList[index];
# 							var todayIndexItem = todayIndexItemList[index];
# 							var todayIndexDealTrendLink = new Array("/sise/sise_trans_style.nhn?sosok=01", "/sise/sise_trans_style.nhn?sosok=02");
#
# 							var oTemplate = jindo.$Template("todayIndexItemTemplate");
# 							var values = jindo.$H(getDealTrendTemplateValues(todayIndexDealTrend));
# 							var tmpMap1 = jindo.$H(getFluctuationTemplateValues(todayIndexItem));
# 							var tmpMap2 = jindo.$H(getIndexItemLinkTemplateValues(todayIndexDealTrendLink, index));
#
# 							tmpMap1.forEach(function(v, k, o) {
# 								values.add(k, v);
# 							});
#
# 							tmpMap2.forEach(function(v, k, o) {
# 								values.add(k, v);
# 							});
#
# 							jindo.$Element(value).html(oTemplate.process(values.$value()));
# 						}
# 					}, this);
#
# 					// 오늘의 증시 코스피200 투자매매동향
# 					jindo.$Element(jindo.$$.getSingle(".dsc_area2")).html(jindo.$Template("todayKpi200Template").process(getDealTrendTemplateValues(todayIndexDealTrendList[2])));
#
# 					// 오늘의 증시 코스피200 프로그램
# 					var trendProgram = new TrendProgram(kospiTrendProgram);
# 					var kospiDifferenceReal = trendProgram.getDifferenceReal();
# 					var kospiBiDifferenceReal = trendProgram.getBiDifferenceReal();
# 					var kospiTotalReal = trendProgram.getTotalReal()
#
# 					var kospiProgramClass = "dd2 " + setUpDnClass(kospiTotalReal);
#
# 					kospiTotalReal = changeNumberFormat(Math.round(kospiTotalReal/100000000));
# 					kospiTotalReal = (kospiBiDifferenceReal + kospiDifferenceReal > 0) ? "+" + kospiTotalReal : "" + kospiTotalReal;
#
# 					var elKospiProgram = jindo.$Element(jindo.$$.getSingle("#_kospiProgram"));
# 					elKospiProgram.className(kospiProgramClass);
#
# 					var sHtml = "";
# 					sHtml = "<a href='/sise/sise_program.nhn?sosok=01' onClick='clickcr(this, \"tsc*o.program\", \"\", \"\", event);'>" + kospiTotalReal + "<span>억</span></a>";
# 					elKospiProgram.html(sHtml);
#
# 					// 업종상위
# 					jindo.$A(jindo.$$(".section_top_first .list_rank li")).forEach(function(oElement, index) {
# 						var groupTopItem = groupTopList[index];
# 						var uiCount = index + 1;
# 						var typeNo = groupTopItem.typeNo;
# 						var typeChangeRate = groupTopItem.typeChangeRate;
#
# 						var sHtml = "";
#
# 						sHtml += "<span class='info_num info_num" + uiCount + "'><span class='blind'>" + uiCount + "</span></span><p class='item'><a href='/sise/sise_group_detail.nhn?type=upjong&no=" + typeNo + "' onClick='clickcr(this, \"tos.cat" + uiCount + "\", \"upjong_" + typeNo +"\", \"\", event);'>";
# 						sHtml += "<strong>" + cutStringByByte(groupTopItem.typeName, 15, "..") + "</strong></a>";
#
# 						if (typeChangeRate > 0) {
# 							sHtml += "<em class='up'>+" + changeNumberFormat(typeChangeRate.toFixed(2)) + "%</em>";
# 						} else if (typeChangeRate < 0) {
# 							sHtml += "<em class='down'>" + changeNumberFormat(typeChangeRate.toFixed(2)) + "%</em>";
# 						} else {
# 							sHtml += "<em class='steady'>" + changeNumberFormat(typeChangeRate.toFixed(2)) + "%</em>";
# 						}
# 						sHtml += "</p>";
#
# 						for (i = 0; i < groupTopItem.itemList.length; i++) {
# 							var groupTopDetailItem = groupTopItem.itemList[i];
# 							var code = groupTopDetailItem.code;
# 							var changeRate = groupTopDetailItem.changeRate;
#
# 							sHtml += "<p>";
# 							sHtml += "<a href='/item/main.nhn?code=" + code + "' onClick='clickcr(this, \"tos.list" + i + "\", \""+ code + "\", \"" + i + "\", event);'>";
# 							sHtml += cutStringByByte(groupTopDetailItem.name, 10, "..") + "</a>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<em class='up'>+" + changeNumberFormat(changeRate.toFixed(2)) + "%</em>";
# 							} else if (changeRate < 0) {
# 								sHtml += "<em class='down'>" + changeNumberFormat(changeRate.toFixed(2)) + "%</em>";
# 							} else {
# 								sHtml += "<em class='steady'>" + changeNumberFormat(changeRate.toFixed(2)) + "%</em>";
# 							}
# 							sHtml += "</p>";
# 						}
#
# 						jindo.$Element(oElement).html(sHtml);
#
# 					}, this);
#
# 					// 테마상위
# 					jindo.$A(jindo.$$(".group_top .list_rank li")).forEach(function(value, index) {
# 						var themeTopItem = themeTopList[index];
# 						var uiCount = index + 1;
#
# 						var sHtml = "";
# 						sHtml += "<span class='info_num info_num" + uiCount + "'><span class='blind'>" + uiCount + "</span></span><p class='item'><a href='/sise/sise_group_detail.nhn?type=theme&no=" + themeTopItem.typeNo + "' onClick='clickcr(this, \"pol.type" + uiCount + "\", \"thema_" + themeTopItem.typeNo +"\", \"\", event);'>";
# 						sHtml += "<strong>" + cutStringByByte(themeTopItem.typeName, 15, "..") + "</strong></a>";
#
# 						if (themeTopItem.typeChangeRate > 0) {
# 							sHtml += "<em class='up'>+" + changeNumberFormat(themeTopItem.typeChangeRate.toFixed(2)) + "%</em>";
# 						} else if (themeTopItem.typeChangeRate < 0) {
# 							sHtml += "<em class='down'>" + changeNumberFormat(themeTopItem.typeChangeRate.toFixed(2)) + "%</em>";
# 						} else {
# 							sHtml += "<em class='steady'>" + changeNumberFormat(themeTopItem.typeChangeRate.toFixed(2)) + "%</em>";
# 						}
# 						sHtml += "</p>";
#
# 						for (i = 0; i < themeTopItem.itemList.length; i++) {
# 							var themeTopDetailItem = themeTopItem.itemList[i];
#
# 							sHtml += "<p>";
# 							sHtml += "<a href='/item/main.nhn?code=" + themeTopDetailItem.code + "' onClick='clickcr(this, \"tos.list" + i + "\", \""+ themeTopDetailItem.code + "\", \"" + i + "\", event);'>";
# 							sHtml += cutStringByByte(themeTopDetailItem.name, 10, "..") + "</a>";
#
# 							if (themeTopDetailItem.changeRate > 0) {
# 								sHtml += "<em class='up'>+" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							} else if (themeTopDetailItem.changeRate < 0) {
# 								sHtml += "<em class='down'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							} else {
# 								sHtml += "<em class='steady'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							}
# 							sHtml += "</p>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					// 거래상위
# 					jindo.$A(jindo.$$("#_topItems1 tr")).forEach(function(value, index) {
# 						var topItem = topItems[0][index];
# 						var changeVal = topItem.changeVal;
# 						var changeRate = topItem.changeRate;
# 						var uiCount = index + 1;
# 						var itemcode = topItem.code;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th><a href='/item/main.nhn?code=" + itemcode + "' onClick='clickcr(this, \"spe.slist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += topItem.name + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 						if (changeRate> 0) {
# 							sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 						} else if (changeRate < 0) {
# 							changeRate = changeRate * -1;
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 						} else {
# 							sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 							sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
# 					});
#
# 					// 상한가
# 					jindo.$A(jindo.$$("#_topItems2 tr")).forEach(function(value, index) {
# 						var topItem = topItems[1][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.nhn?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
#
# 							if (changeVal != 0) {
# 								sHtml += "<td><em class='bu_p bu_pup2'><span class='blind'>상한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 하한가
# 					jindo.$A(jindo.$$("#_topItems3 tr")).forEach(function(value, index) {
# 						var topItem = topItems[2][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.nhn?code=" + itemcode + "' onClick='clickcr(this, \"spe.blist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeVal != 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn2'><span class='blind'>하한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
#
# 					// 시가총액 상위
# 					jindo.$A(jindo.$$("#_topItems4 tr")).forEach(function(value, index) {
# 						var topItem = topItems[3][index];
# 						var changeVal = topItem.changeVal;
# 						var changeRate = topItem.changeRate;
# 						var uiCount = index + 1;
# 						var itemcode = topItem.code;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th><a href='/item/main.nhn?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += topItem.name + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 						if (changeRate> 0) {
# 							sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 						} else if (changeRate < 0) {
# 							changeRate = changeRate * -1;
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 						} else {
# 							sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 							sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
# 					});
#
# 					// 인기 검색 종목
# 					jindo.$A(jindo.$$(".aside_popular tbody tr")).forEach(function(value, index) {
# 						var popularItem = searchList[index];
# 						var uiCount = index + 1;
# 						var changeVal = popularItem.changeVal;
# 						var itemcode = popularItem.itemcode;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th scope=\'row\'><em>" + uiCount + ".</em><a href=\'/item/main.nhn?code=" + itemcode + "\' onClick='clickcr(this, \"boa.list\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += cutStringByByte(popularItem.itemname, 12, "..") + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(popularItem.nowVal) + "</td>";
#
# 						if (popularItem.risefall == 1) {
# 							sHtml += "<td><em class=\'bu_p bu_pup2\'><span class=\'blind\'>상한가</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 2) {
# 							sHtml += "<td><em class=\'bu_p bu_pup'><span class=\'blind\'>상승</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 3) {
# 							sHtml += "<td><span class=\'tah p11\'> 0 </span></td>";
# 						} else if (popularItem.risefall == 4) {
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn2\'><span class=\'blind\'>하한가</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else{
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn'\><span class=\'blind\'>하락</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					startInformationTimer();
# 				}
# 			}
# 		},
# 		timeout : 2,
# 		ontimeout : function() {
# 			startInformationTimer();
# 		},
# 		async : true
# 	});
# 	oUpdateAjax.request();
# }
#
# function getIndexItemLinkTemplateValues(todayIndexDealTrendLink, index) {
# 	values = {
# 			_todayIndexDealTrendLink : todayIndexDealTrendLink[index],
# 			_todayIndexItemUpperLink : "/sise/sise_upper.nhn?sosok=" + index,
# 			_todayIndexItemRiseLink : "/sise/sise_rise.nhn?sosok=" + index,
# 			_todayIndexItemSteadyLink : "/sise/sise_steady.nhn?sosok=" + index,
# 			_todayIndexItemFallLink : "/sise/sise_fall.nhn?sosok=" + index,
# 			_todayIndexItemLowerLink : "/sise/sise_lower.nhn?sosok=" + index
# 	};
#
# 	return values;
# }
#
# // up, down, same 클래스 생성 기능
# function setUpDownClass(sChangeVal, eValue) {
# 	if (sChangeVal > 0) {
# 		jindo.$Element(eValue).className("up");
# 	} else if (sChangeVal < 0) {
# 		jindo.$Element(eValue).className("down");
# 	} else {
# 		jindo.$Element(eValue).className("same");
# 	}
# }
#
# function setUpDnClass(value){
# 	var className = "";
# 	if (value > 0){
# 		className = "up";
# 	} else if(value < 0){
# 		className = "dn";
# 	}
#
# 	return className;
# }
#
# function initChartRefresh() {
# 	var chartRefreshTime = 60000;
#
# 	setInterval('doChartRefresh()', chartRefreshTime);
# }
#
# function doChartRefresh() {
# 	var sSidCode = (new Date()).getTime();
# 	jindo.$A(jindo.$$("div.chart_area img")).forEach(function(v) {
# 		var sSrc = jindo.$Element(v).attr("src");
# 		sSrc = sSrc.substr(0, sSrc.indexOf("sidcode=") + 8) + sSidCode;
#
# 		jindo.$Element(v).attr("src", sSrc);
# 	}, this);
# }
#
# function mainPageDomReadyFn() {
# 	doUpdateInformation();
# 	Polling.init();
# 	initChartRefresh();
# }
#
# function togglePannel(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# function showPannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='block';
# }
#
# function hidePannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='none';
# }
#
# // 1분 리플레시, 실시간 시세 폴링, 이미지 리플레시
# jindo.$Fn(mainPageDomReadyFn).attach(document, "domready");
#
# </script>
#  </body>
# </html>

# %%
resp = requests.get('http://naver.com')
print(resp.encoding)
resp = requests.get('http://finance.naver.com')
print(resp.encoding)
# Out:
# UTF-8
# euc-kr
